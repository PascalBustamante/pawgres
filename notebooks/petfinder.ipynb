# %%
import sys
sys.path.append("..")

from src.utils.db import DatabaseConnector
#from src.utils.logging import Logger
from src.extract.petfinder import PetfinderAPI
from config.config import config

# %%
config(section='petfinder')
# Out:
# c:\dev\python\Data Analysis\pawgres\notebooks
# ../config/config.ini
# ('api_key', 'I9W61HSD43LqdvfdyoeLaYFvD76OZuKma8wfs0f0yeddur54Gg')
# ('api_secret', 'zEibYWOgIPGwZk058QT21Xfzx67OGgpNAQfeYQcl')
# ('base_url', 'https://api.petfinder.com/v2')
# {'api_key': 'I9W61HSD43LqdvfdyoeLaYFvD76OZuKma8wfs0f0yeddur54Gg',
#  'api_secret': 'zEibYWOgIPGwZk058QT21Xfzx67OGgpNAQfeYQcl',
#  'base_url': 'https://api.petfinder.com/v2'}

# %%
api = PetfinderAPI()
dogs_data = api.get_dogs(location="New York, NY", distance=50, limit=100)
# Out:
# c:\dev\python\Data Analysis\pawgres\notebooks
# config/config.ini
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 api = PetfinderAPI()
#       2 dogs_data = api.get_dogs(location="New York, NY", distance=50, limit=100)
#
# File c:\dev\python\Data Analysis\pawgres\notebooks\..\src\extract\petfinder.py:10, in PetfinderAPI.__init__(self, filename, section)
#       9 def __init__(self, filename="config/config.ini", section="petfinder"):
# ---> 10     self.credentials = config(filename=filename, section=section)
#      11     self.access_token = None
#      12     self.token_expiry = 0
#
# File c:\dev\python\Data Analysis\pawgres\notebooks\..\config\config.py:19, in config(filename, section)
#      16         print(param)
#      18 else:
# ---> 19     raise Exception(f"Section {section} not found in {filename}")
#      21 return config_dict
#
# Exception: Section petfinder not found in config/config.ini
